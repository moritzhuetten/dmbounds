# %%
import h5py
import numpy as np
import pandas as pd

# %%
hf = h5py.File("HDMSpectra.hdf5", 'r')
print("##  List of keys : ", list(hf.keys())) # print the keys in the data file
#list(hf)
print(' ')
print(' ')
print("##  Q value of the reaction : ", hf['high_leptons']['Q_2212'][:]) 
print(' ')
print(' ')
print("##  X values ( as defined in literature) : ")
print(' ')
print(hf['high_leptons']['x_11'][:])
print(' ')
print(' ')
print(' ')
print(' ')
print("##  FF values ( as defined in literature) : ")
print(' ')
print(hf['high_leptons']['FF_11'][:])
# Out:
# ##  List of keys :  ['delta_coeff', 'high_gauge', 'high_higgs', 'high_leptons', 'high_quarks']
#
#
# ##  Q value of the reaction :  [ 2.69897  3.       3.4      3.6      4.       4.2      4.6      5.4
#   8.2     10.8     13.6     16.2     19.     ]
#
#
# ##  X values ( as defined in literature) :
#
# [1.00001056e-06 9.99425630e-06 1.77610980e-05 3.15953690e-05
#  4.21405541e-05 5.62052719e-05 7.49641919e-05 9.99840385e-05
#  1.15354565e-04 1.33221154e-04 1.43166825e-04 1.53854993e-04
#  1.77684687e-04 1.90949798e-04 2.05205221e-04 2.36988249e-04
#  2.73693963e-04 3.16084808e-04 5.62285967e-04 1.00025531e-03
#  1.33276440e-03 1.53918842e-03 1.77758425e-03 1.91029041e-03
#  2.05290380e-03 2.37086598e-03 2.73807544e-03 3.16215981e-03
#  4.21755375e-03 5.62519311e-03 1.00067041e-02 1.77832193e-02
#  2.37184987e-02 3.16347209e-02 4.21508681e-02 5.62190282e-02
#  7.49825394e-02 1.00008510e-01 1.33253760e-01 1.77728175e-01
#  2.05255445e-01 2.37046252e-01 2.54743022e-01 2.73760950e-01
# ...
